# %% [markdown]
# HOMEWORK 2

# %% [markdown]
# Bài 1

# %%
a=float(input())
b=float(input())
print(a*b)
print((a+b)/2)

# %% [markdown]
# Bài 2

# %%
r=float(input())
print(r*r*3.14)
print(2*3.14*r)

# %% [markdown]
# Bài 3

# %%
a,b,c=map(float,input().split())
p=(a+b+c)/2
chuvi=a+b+c
s=(p*(p-a)*(p-b)*(p-c))**0.5
if a+b<c and a+c<b and b+c<a:
    print("Khong la ba canh cua mot tam giac")
 
elif a*a+b*b==c*c or a*a+c*c==b*b or b*b+c*c==a*a:

    print("tam giac vuong")
    print(s)
    print(chuvi)
elif a==b and b==c:
    print("tam giac deu")
    print(s)
    print(chuvi)
elif a==b or b==c or a==c:
    print("tam giac can")
    print(s)
    print(chuvi)
else:
    print("tam giac thuong")
    print(s)
    print(chuvi)
# Out:
# tam giac can
# 4.47213595499958
# 10.0

# %% [markdown]
# bài 4

# %%
a,b=map(float,input().split())
if a==0:
    if b==0:
        print("phuong trinh co vo so nghiem")
    else:
        print("phuong trinh vo nghiem")
else:
    print(-b/a)

# %% [markdown]
# bài 5

# %%
a,b,c=map(float,input().split())
delta=b*b-4*a*c
if a==0:
    if b==0:
        if c==0:
            print("phuong trinh co vo so nghiem")
        else:
            print("phuong trinh vo nghiem")
    else:
        print(-c/b)
elif delta<0:
    print("phuong trinh vo nghiem")
elif delta==0:
    print("phuong trinh co nghiem kep: ",-b/(2*a))
else:
    x1=(-b+delta**0.5)/(2*a)
    x2=(-b-delta**0.5)/(2*a)
    print("phuong trinh co hai nghiem phan biet: ",x1," va ",x2)
# Out:
# -2.5

# %% [markdown]
# bài 6

# %%
a,b,c,d=map(float,input().split())
print(max(a,b,c,d))
# Out:
# 89.0

# %% [markdown]
# bài 7

# %%
a,b,c,d=map(float,input().split())
print(min(a,b,c,d))

# %% [markdown]
# bài 8

# %%
a,b,m,c,d,n=map(float,input().split())
d= a*d-b*c
dx= m*d-b*c
dy= a*n-m*c 
if a==0:
    y=m/b
    print(x=(n-d*y)/c)
    print(y)
elif b==0:
    x=m/a
    print(y=(n-c*x)/d)
    print(x)
elif d==0:
    print("he phuong trinh vo nghiem")
elif dx==0 and dy==0:
    print("he phuong trinh co vo so nghiem")
else: 
    print(dx/d)
    print(dy/d)
# Out:
# 6.2
# 1.0

# %% [markdown]
# bài 9

# %%
giay=int(input())
gio=giay//3600
phut=(giay%3600)//60
giay=giay%60
print(gio,phut,giay)
# Out:
# 0 2 9

# %% [markdown]
# bài 10

# %%
r=float(input())
a,b=map(float,input().split())

x,y=map(float,input().split())
ptdt=(x-a)**2+(y-b)**2-r*r
if ptdt==0:
    print("diem thuoc duong tron")
else:
    print("diem khong thuoc duong tron")
# Out:
# diem thuoc duong tron

# %% [markdown]
# bài 11

# %%
x,y=map(float,input().split())
print(x**y)
# Out:
# 8.0

# %% [markdown]
# BaiTapTuan3_new

# %% [markdown]
# W3A1

# %%
n=int(input())
n1=n%10 #donvi
conlai1=n//10
n2=conlai1%10 #chuc
conlai2=conlai1//10
n3=conlai2%10 #tram
daonguoc=n1*100+n2*10+n3
print(daonguoc)
# Out:
# 654

# %% [markdown]
# W3A2

# %%
a = int(input())
b = int(input())
a = a ^ b
b = a ^ b
a = a ^ b

print(f"a = {a}, b = {b}")
# Out:
# a = 2, b = 1

# %% [markdown]
# W3A3

# %%
n = int(input())
if n > 0 and (n & (n - 1)) == 0:
    print("true")
else:
    print("false")
# Out:
# true

# %% [markdown]
# W3A4

# %%
m,n=map(float,input().split())
if n==0: print("khong chia duoc cho 0")
else: print(m//n)
# Out:
# khong chia duoc cho 0

# %% [markdown]
# W3A5

# %%
import math
m,n=map(float,input().split())
if n==0: print("khong chia duoc cho 0")
else: print(math.ceil(m/n))
# Out:
# 3

# %% [markdown]
# W3A6

# %%
x=int(input())
if x%2==0:
    print("even")
else:    print("odd")
# Out:
# odd

# %% [markdown]
# W3A7

# %%
a,b=map(int,input().split())
if (a<0 or b<0) and a*b>0:
    print("yes")
else:    print("no")
# Out:
# no

# %% [markdown]
# W3A8

# %%
a=str(input())
b=str(input()) 
if len(a)>len(b):
    print("true")
else:print("false")
# Out:
# true

# %% [markdown]
# W3A9

# %%
a,b,c=map(int,input().split())
if a+b>c and a+c>b and b+c>a:
    print("yes")
else:print("no")
# Out:
# no

# %% [markdown]
# W3A10

# %%
a,b,c,d=map(int,input().split())
print(max(a,b,c,d))

# %% [markdown]
# W3A11

# %%
a,b,c=map(float,input().split())

if a+b<c and a+c<b and b+c<a:
    print("Khong la ba canh cua mot tam giac")
 
elif a*a+b*b==c*c or a*a+c*c==b*b or b*b+c*c==a*a:
      print("tam giac vuong")
elif a==b and b==c:
    print("tam giac deu")
elif a==b or b==c or a==c:
    print("tam giac can")
else:
    print("tam giac thuong")
# Out:
# tam giac vuong

# %% [markdown]
# W3A12

# %%
n=int(input()) 
if n%400==0 or (n%4==0 and n%100!=0):
    print("yes")
else:print("no")
# Out:
# yes

# %% [markdown]
# W3A13

# %%
kwh = float(input())
tong_tien = 0
if kwh <= 50:
  tong_tien = kwh * 1500
elif kwh <= 100:
    tong_tien = (50 * 1500) + (kwh - 50) * 2000
else:
    tong_tien = (50 * 1500) + (50 * 2000) + (kwh - 100) * 3000
print(tong_tien)
# Out:
# 60000.0

# %% [markdown]
# W3A14

# %%
a,b=map(float,input().split())
if a==0:
    if b==0:
        print("vo so nghiem")
    else:
        print("vo nghiem")
else:print(round(-b/a,2))
# Out:
# vo so nghiem

# %% [markdown]
# W3A15

# %%
diemtb=float(input())
if diemtb>=8:
    print("Gioi")
elif diemtb>=6.5:
    print("Kha")
elif diemtb>=5:
    print("Trung binh")
else:
    print("Yeu")
# Out:
# Yeu

# %% [markdown]
# W3A16

# %%
n=float(input())
#tronxuong
if n>=0 or n==int(n):
    tronxuong=int(n)
else: 
    tronxuong=int(n) - 1
#tronlen
if n<=0 or n==int(n):
    tronlen=int(n)
else: 
    tronlen=int(n) + 1
#songuyyengannhat
thapphan=n - tronxuong
if thapphan<0.5:
    gannhat=tronxuong
else:
    gannhat=tronlen
print(tronlen,tronxuong,gannhat)
# Out:
# -6 -5 -6

# %% [markdown]
# W3A17

# %%
a,b,c,d=map(float,input().split())
q=b/a
if c==q*b and d==q*c:
    print("cap so nhan")
else:
    print("khong phai cap so nhan")
# Out:
# khong phai cap so nhan
